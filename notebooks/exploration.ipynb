# %% [markdown]
# # Fraud Detection Pipeline — Exploration
#
# Use this notebook to explore the data and debug the pipeline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('../data/fraud_detection.csv')
print(f'Dataset shape: {df.shape}')
print(f'Fraud rate: {df["is_fraud"].mean():.2%}')
df.head()

# %%
# Class distribution
print(df['is_fraud'].value_counts())
print(f'\nImbalance ratio: {(df["is_fraud"]==0).sum() / (df["is_fraud"]==1).sum():.1f}:1')

# %%
# Feature distributions
df.describe()

# %%
# Run the pipeline and see what happens
from src.pipeline import run_pipeline
report = run_pipeline()

# %%
# Run the tests — how many fail?
# !pytest -v
